# %% [markdown]
# # Computer Architecture for Data Scientists: from the transistor to The Cloud
#
# ### Kevin Moore
# ** Data Science BIG, April 11 2017 **
#
# It's an amazing time to be a data scientist or a computer-savvy scientist. My laptop is like a supercomputer from 20 years ago. And, more computing power than most of us can imagine is available to all of us in the public cloud.
#
# About Me:
# * CEO Quilt Data
# * PhD Computer Architecture
# * MP memory systems & DBMS
# * Oracle and Sun Labs
# * **not a biologist**
#
# ** Goal today: **
# Explain a little about how computers work and what makes them go fast. Understanding that will (hopefully) help you:
# * write better software
# * make more informed software choices

# %% [markdown]
# ### Example: intersect genomic regions
#
# Let's say for example that we want to take a published CRISPR library from the well-known Lander-Sabatini Lab and intersect it with the set of common genetic variants known to be associated with a medial condition (published as part of the CLINVAR dataset).

# %%
# Why is this so much faster?
def intersect_fast(a, b):
    matches = None

    a_chrs = a.groupby('Chromosome')
    b_chrs = b.groupby('Chromosome')
    
    for a_chr, a_grp in a_chrs:
        b_grp = b_chrs.get_group(a_row['Chromosome'])
        for idx, a_row in a_grp.iterrows():
            a_match = b_grp.loc[(b_grp['start'] < a_row['end']) & ((b_grp['end'] > a_row['start']))]
            matches = pd.concat([matches, a_match]) if matches is not None else a_match
    return matches

# %%
# than this?
def intersect_naive(a, b):
    matches = []
    for a in rowmajor_a:
        for b in rowmajor_b:
            if a[0] == b[0] and int(a[1]) < int(b[2]) and int(a[2]) > int(b[1]):
                matches.append((a, b))
    return matches

# %% [markdown]
# The code in these two examples perform the same genomic intersection. Both are implemented in Python and neither uses explicit multiprocessing. But, the second example runs more than 100x faster. I'll use these loops and problem to illustrate some of the central concepts and techniques in computer architecture and explain some techniques for writing fast code.

# %% [markdown]
# ### Key Concepts in Computer Architecture: Latency and Bandwidth
# **Latency**
# * how long a single unit of a resource takes to arrive
# * affected by size and distance of components
# * changes slowly with technology generation (like clock rate)
#
# **Bandwidth**
# * how much of a resource can be delivered per unit time
# * can often 'buy' more with money/cost, power, area, etc.
# * gets cheaper with tech
#
# The architect's goal is to be limited by bandwidth and "buy" only the bandwidth needed for the given system. To get there, we try to **hide latency** (by doing something else instead of waiting).

# %% [markdown]
# ### Computer Architect’s secret weapons
# **Locality**
# Architects take advantage of locality to **reduce latency** by:
# * using smaller structures (e.g. caches instead of memory)
# * making fewer, larger lookups (e.g. on disk and in memory)
#
# **Speculation**
# Speculation is making a prediction with the ability to undo any actions if the prediction turns out to be wrong. Speculation allows architects to **hide latency** by designing processors to do useful work while waiting for long-latency results.

# %% [markdown]
# ### Von Neumann Model (1945)
# In many ways computers haven’t changed much since the late 1940’s. Jon Von Neumann is credited with introducing the stored program computer in 1945. It had the following basic set of components:
#
# * Memory
# * Memory Address Register (MAR)
# * Memory Data Register (MDR)
# * ALU/TEMP(registers)
# * Control
# * I/O
#
# Fetch (instruction)
# Decode
# Evaluate Address
# Fetch operands
# Execute operation
# Store result
#
# Since then, switches are much smaller and faster (now transistors on ICs). Computers got so much smaller, faster and cheaper they became common in offices and homes in the 1980s. Even since then, computers have gotten much, much, faster. For example:
#
# | Intel 386 (1989) | MacbookPro/Intel Skylake (2016)|
# | ------------ | :-----------: |
# | 33 MHz  | 2.9 GHz |
# | 275K transistors | more than 1B Transistors |
# | 4.3 MIPS  | 317 GIPS (74,000x 386)  ||
# ~100x faster clock
# ~740x improved architecture (**parallelism**)

# %% [markdown]
# ### But my macbook only has 4 cores, where does that parallelism come from?
# #### mostly instruction-level parallelism
#
# * **Pipelining**
#     + ~5x parallelism
#     + example below
#
# * **Superscalar**
#     + ~2x more parallelism
#     + Complicated, very cool, next lecture
#
# * **SIMD/Vector Instructions**
#     + 16x+ parallelism
#     + only for very regular execution patterns

# %% [markdown]
# ### Pipelined Execution
#
# Each instruction takes multiple (5 or more in the example below), but multiple instructions are executing at the same time. The example below shows a simple processor pipeline with 5 stages. Instructions move right to left as they execute various stages.
#
# ![title](pipeline_stages.jpg)
#
# Modern Intel processors have more complicated pipelines that are both **super-scalar** (fetch and execute multiple instructions per cycle) and **out-of-order** (the processor executes instructions as soon as they are ready possibly bypassing earlier waiting instructions).
#
# But, to make that work procs need:
# * **Caches**
# * **Branch prediction** (guessing)

# %% [markdown]
# ### Caches
#
# Computer memory system is a hierarchy:
# * Registers (many accesses per cycle)
# * L1 Cache - usually 1 cycle (10s of KBs)
# * L2 Cache - usually 2-3 cycles (100s of KBs)
# * L3 Cache - 10s of cycles (MBs)
# * Main memory - 100s of cycles (GBs)
# * Virtual memory (SSD) - 1000s of cycles (100s of GBs)
#
# Caches store a small subset of memory that is loaded on demand. When a processor loads a memory location, it looks in its closest/smallest caches first. If the memory address isn't cached, it issues a request to higher levels of memory system. When the data are returned, they're loaded into the cache with the expectation that they're likely to be accessed again. Most software has a small working set in memory that is accessed more frequently than other locations. Caches (ideally) hold that working set for the duration of a program and speedup most memory accesses.
#
# Caches are designed to take advantage of two forms of locality: **temporal locality** (the same memory location is accessed repeatedly in a short period of time) and **spatial locality** (adjacent memory locations are accessed together).

# %% [markdown]
# ### Branch Prediction
#
# Instructions that change the flow of instructions (e.g. to re-execute the body of a loop) are called branches. To avoid stalling the processor's pipeline, the instructions following a branch need to be fetched before the branch itself is executed.
#
# ![title](pipeline-branch-pred.jpg)
#
# Processors speculate (guess) whether or not the branch will be taken, and flush the pipeline if they're wrong. Flushes are only a little more expensive than not speculating and can help bring instructions and data into processor caches faster. From a software developer's perspective, our goal is to write software with control flow that's easy to guess (e.g., **short tight loops with little internal branching**).

# %% [markdown]
# ### Back to bio…
#
# Why is this so slow?

# %%
def intersect_naive(rowmajor_a, rowmajor_b):
    matches = []
    for a in rowmajor_a:
        for b in rowmajor_b:
            if a[0] == b[0] and int(a[1]) < int(b[2]) and int(a[2]) > int(b[1]):
                matches.append((a, b))
    return matches

# %% [markdown]
# ** First some code to setup our experiments**

# %%
import csv
import signal
import time

# Datasets used in the examples
# see https://quiltdata.com for more info
# about Quilt.
from quilt.data.kmoore import CAforDS

def handler(signum, frame):
    print('Stopped')
    signal.alarm(0)
    raise TimerException("Alarm")
    
class TimerException(Exception):
    pass

# Cut the examples off if they haven't finished
# at the end of the timer so you don't have to
# wait all day.
signal.signal(signal.SIGALRM, handler)
timer = 20

# %% [markdown]
# ### Naive Implementation: Nested Loops over rows

# %%
# CRISPR Library from Lander-Sabatini Lab:
# - gRNA Name
# - Gene
# - Chromosome
# - Start
# - Stop
# - Strand
# - Sequence
# - Sequence revComp
# - oligo_F
# - oligo_R
# - sgA1BG_1

with open(CAforDS.raw.lander(), 'r') as a_bed:
    bedreader = csv.reader(a_bed, delimiter='\t')
    rowmajor_a = [row for row in bedreader]

# %%
# Clinvar Common-and-Known
# - Chromosome
# - Position
# - RSID
# - Ref
# - Alt
# - Info
with open(CAforDS.raw.clinvar(), 'r') as b_bed:
    bedreader = csv.reader(b_bed, delimiter='\t')
    rowmajor_b = [row for row in bedreader if not row[0].startswith('#')]

# %%
count = 0
a_len = len(rowmajor_a)
b_len = len(rowmajor_b)
outrows = []
signal.alarm(timer)
try:
    for a in rowmajor_a[1:]:
        # Read a row from A
        a_chr = a[2]
        a_start = int(a[3])
        a_end = int(a[4])
        for b in rowmajor_b[1:]:
            # Read a row from B
            b_chr = "chr%s" % b[0]
            b_pos = int(b[1])
            if a_chr == b_chr and a_start <= b_pos and b_pos <= a_end:
                outrows.append(b)
            count += 1
    print("Finished")
except TimerException:
    print("Excecuted %ss" % timer)
finally:
    signal.alarm(0)
    miterations = count/1000000.0
    pct = count/(a_len*b_len)*100.0
    print("Completed %sM iterations (%0.2f%%)" % (miterations, pct))
# Out:
# Stopped
# Excecuted 20s
# Completed 26.136149M iterations (2.48%)

# %% [markdown]
# ### Why is this so slow?
#
# On my laptop, I get about 2.5% through the calculation in 20s so the whole thing would take around 14 minutes when the fast version will execute in about 5s.
#
# Problem 1: **Algorithm**
#
# An all-to-all comparison requires A * B operations.

# %%
acount = len(rowmajor_a)
bcount = len(rowmajor_b)
print("%d x %d = %d (%.2fB)" % (acount, bcount, acount*bcount, (float(acount)*bcount/(10**9))))
# Out:
# 181131 x 5807 = 1051827717 (1.05B)

# %% [markdown]
# ### Smarter approach: Partition by chromosome
#
# Only genomic regions on the same Chromosome could possibly overlap, so we can dramatically reduce the number of comparisons by partitioning the inputs by chromosome and only comparing each region to the subset in the opposite input that matches its chromosome.

# %%
cc_a = {}
cc_b = {}
# Count B by chromosome
for bidx, b in enumerate(rowmajor_b[1:]):
    chrm = "chr%s" % b[0]
    if chrm not in cc_b:
        cc_b[chrm] = 0
    cc_b[chrm] += 1 
    
# Count A by chromosome
for aidx, a in enumerate(rowmajor_a[1:]):
    chrm = a[2]
    if chrm not in cc_a:
        cc_a[chrm] = 0
    cc_a[chrm] += 1 

#print(cc_a.keys())
#print(cc_b.keys())

total = 0
for chrm, count in cc_b.items():
    total += count*cc_a[chrm] if chrm in cc_a else 0
print("%d (%dM) operations" % (total, total/1000000.0))
# Out:
# 53839387 (53M) operations

# %% [markdown]
# Reduces the work needed from 1B operations to 53M (**20x**).

# %%
count = 0
outrows = []
signal.alarm(timer)
parts = {}
try:
    # Partition B
    starttime = time.time()
    for bidx, b in enumerate(rowmajor_b[1:]):
        chrm = "chr%s" % b[0]
        if chrm not in parts:
            parts[chrm] = []
        parts[chrm].append(bidx)
    
    # Iterate through A
    for a in rowmajor_a[1:]:
        a_chr = a[2]
        a_start = int(a[3])
        a_end = int(a[4])
        if a_chr in parts:
            for bidx in parts[a_chr]: 
                b = rowmajor_b[bidx+1]
                b_chr = "chr%s" % b[0]
                b_pos = int(b[1])
                if a_start <= b_pos and b_pos <= a_end:
                    outrows.append((a, b))
                count += 1            
    endtime = time.time()
    matches = len(outrows)
    print("Done, found %s matches in %ds" % (matches, endtime-starttime))

except TimerException:
    print("Excecuted %ss" % timer)
finally:
    signal.alarm(0)
    miterations = count/1000000.0
    pct = count/total*100.0
    print("Completed {it}M iterations ({pct:.2f}%)".format(it=miterations, pct=pct))
# Out:
# Stopped
# Excecuted 20s
# Completed 20.872505M iterations (38.77%)

# %% [markdown]
# That's a lot faster, but not quite 20x faster because the partitioning takes time.
#
# But, it's still **slow**. What else is going wrong?
#
# Problem 2: **Interpretation**
# Python is an interpreted language so even basic operations (e.g. adding a pair of numbers) becomes a much longer set of steps. But, Python has hooks for developers to call out to functions written in C, which is compiled into machine-native binary code. That lets them publish Python libraries where the inner loops run at full speed for most of the calculation.
#
# Problem 3: **Inefficent use of caches**

# %% [markdown]
# ### What happens to caches?
#
# If we read genomic interval data into memory in the way it's stored in a BED file, each genomic interval record (chromosome, start, end, strand, score, etc.) will be stored contiguously. Running the code above, the processor will load its caches 64-bytes at a line. As a result, the caches fill up with lots of unused data (score, name, block starts, etc.).
#
# ![title](cache_pollution.jpg)

# %% [markdown]
# ### Branches are hard to predict
#
# Inside the processor, comparing strings is actually more complicated than it looks. The processor has to test if each string is ending after each character as well as testing if the characters from the inputs match. And, mixing the chromosome comparison with a comparison of start and stop only adds to the number of branches the processor has to predict on each iteration of the loop.

# %% [markdown]
# ### Alternative: columnar processing
#
# Instead, we can represent the set of genomic intervals as a collection of arrays:
# * Chromosome []
# * Start []
# * End []
# * ...
#
# ![title](cache_columns.jpg)
#
# Accessing the data as columnar arrays leads to:
# * Better cache locality (only bring in what we need)
# * Less latency (fewer misses)
# * More efficient use of BW (only loading what we need)
# * Tighter loops (less branching)

# %% [markdown]
# Pandas
# ====
#
# Pandas is a popular and very useful data science package for Python. It stores and operates on data in columnar form. It's built on top of numpy, a package of optimized array operations for fast numeric processing in Python.

# %%
import pandas as pd

lander = CAforDS.df.lander()
clinvar = pd.read_csv(CAforDS.raw.clinvar(),
                      sep='\t',
                      comment='#',
                      names=['CHROM', 'POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO'])

# %%
a = clinvar
b = lander

# match chromosome notation (chr<N>)
a['Chromosome'] = a['CHROM'].apply(lambda x: "chr%s" %x)

# %%
print(a.columns)
print(b.columns)
a_len = len(a.index)
b_len = len(b.index)
# Out:
# Index(['CHROM', 'POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO',
#        'Chromosome'],
#       dtype='object')
# Index(['gRNAname', 'gene', 'chr', 'start', 'stop', 'strand', 'sequence',
#        'sequence_revComp', 'oligo_F', 'oligo_R'],
#       dtype='object')

# %%
matches = []
count = 0
signal.alarm(timer)
try:
    starttime = time.time()
    for idx, a_row in a.iterrows():
        a_match = b.loc[(b['chr'] == a_row['Chromosome']) & (b['start'] <= a_row['POS'])
                        & ((a_row['POS'] <= b['stop']))]
        matches.append(a_match)
        count += b_len
    allmatches = pd.concat(matches)
    endtime = time.time()
    print("Done, found %s matches in %ds" % (len(allmatches), endtime-starttime))
except TimerException:
    print("Excecuted %ss" % timer)
finally:
    signal.alarm(0)
    miterations = count/1000000.0
    pct = count/(a_len*b_len)*100.0
    print("Completed %.2fM iterations (%0.2f%%)" % (miterations, pct))
# Out:
# Stopped
# Excecuted 20s
# Completed 210.65M iterations (20.03%)

# %% [markdown]
# That's a lot faster, but not enough to make up for a slow algorithm.

# %% [markdown]
# ### Partition Large Table

# %%
matches = []
count = 0
signal.alarm(timer)
try:
    starttime = time.time()
    b_chr = b.groupby('chr')
    for idx, a_row in a.iterrows():
        chr_grp = b_chr.get_group(a_row['Chromosome'])
        a_match = chr_grp.loc[(chr_grp['start'] <= a_row['POS'])
                              & ((a_row['POS'] <= chr_grp['stop']))]
        if len(a_match.index) > 0:
            matches.append(a_match)
        count += len(chr_grp)
    allmatches = pd.concat(matches)
    endtime = time.time()
    print("Done, found %s matches in %ds" % (len(allmatches), endtime-starttime))
except TimerException:
    print("Excecuted %d iterations" % count)
finally:
    signal.alarm(0)
    miterations = count/1000000.0
    pct = count/total*100.0
    print("Completed %.2fM iterations (%0.2f%%)" % (miterations, pct))
# Out:
# Done, found 462 matches in 17s
# Completed 53.86M iterations (100.03%)

# %% [markdown]
# ### Partition Both Tables

# %%
count = 0
signal.alarm(timer)
matches = []
try:
    starttime = time.time()
    a_chrs = a.groupby('Chromosome')
    b_chrs = b.groupby('chr')
    
    for a_chr, a_grp in a_chrs:
        b_grp = b_chrs.get_group(a_chr)
        for idx, a_pos in a_grp['POS'].iteritems():
            a_match = b_grp.loc[(b_grp['start'] <= a_pos)
                                & ((a_pos <= b_grp['stop']))]
            if a_match.index.any():
                matches.append(a_match)
            count += len(b_grp.index)
    allmatches = pd.concat(matches)
    endtime = time.time()
    print("Done, found %s matches in %ds" % (len(allmatches.index), endtime-starttime))
except TimerException:
    print("Excecuted %d iterations" % count)
finally:
    signal.alarm(0)
    miterations = count/1000000.0
    print("Completed {it}M iterations".format(it=miterations))
# Out:
# Done, found 462 matches in 5s
# Completed 53.85803M iterations

# %% [markdown]
# ### The Cloud
#
# What about working in **The Cloud?** Computer architecture principles still apply: pay careful attention to **latency** and **bandwidth**.
#
# **Avoid moving data**
# Communication to and from cloud-hosted servers is slow. Each message and response suffers from long latency so avoid algorithms that require lots of request and response actions. Data transfer in and out of cloud datacenters is also limited in bandwidth. Moving GB let alone TB of data in or out of the cloud is very slow. It's usually cheaper to send computation to a computer near the data than to send data to a far-away computer. It can also be cheaper and faster to compress files or data before transferring them.
#
# **Use Columnar Databases for *Analytics***
# There are dozens of databases to choose from that are now easily deployable or available as a service from various cloud providers. They're widely different in the way they store and process data and some are much better suited than others for a given application. For analytics and other querying, choose a columnar or vector-based database.
#
# Choose databases like:
# * Druid
# * Redshift (Amazon)
# * BigQuery (Google)
# * SQLServer (Microsoft)
# * Snowflake (on AWS)
#
# Avoid:
# * MongoDB
# * MySQL
# * Postgres
#
# There are also now several query-in-place SQL engines that have very good performance:
# * PrestoDB
# * Hive
# * Athena (Amazon hosted Presto)
# * Drill
#
# **Avoid SELECT * **
# Those columnar databases are amazingly efficient at querying, but most software that connects to them uses an interface that's row-based. That means that pulling a large result out of even a very fast database can be slow. If that database is hosted in a cloud datacenter, getting the result back can take even longer. Instead, move the computation into the database or at least to a computer in the same datacenter.

# %% [markdown]
# ### Review
#
# **Start with your algorithm**
# Even very efficient implementations of inefficient algorithms can be much, much slower than switching to a better more scalable algorithm.
#
# **Optimize sequential before multithreading**
# Modern CPUs can execute many instructions in parallel if the code and inputs let them. Use optimized libraries whenever possible (I highly recommend: **Python + Pandas + Pyspark**). Look for ways to organize your code into tight, regular loops.
#
# **Pay attention to locality**
# Caches are essential for good processor speed so try blocking your loops to cache-size chunks. Partitioning is one very effective technique.
#
# **Choose software and cloud services optimized for your use**
# Use columnar execution for computation intensive applications like data analysis. Use update-focused databases to store rapidly changing datasets.
#
# **Reduce data movement to and from The Cloud**
# Your laptop can billions of operations in the time it takes to get a response from a cloud service and your processor can pull GB/s from its local memory and SSD drive, but you'll be lucky to a few MB/s from even the best Internet services.

# %%
lander = CAforDS.df.lander()
lander
# Out:
#           gRNAname   gene    chr      start       stop strand  \
# 0         sgA1BG_1   A1BG  chr19   58864441   58864461      -
# 1         sgA1BG_2   A1BG  chr19   58862759   58862779      -
# 2         sgA1BG_3   A1BG  chr19   58863731   58863751      +
# 3         sgA1BG_4   A1BG  chr19   58861903   58861923      -
# 4         sgA1BG_5   A1BG  chr19   58861812   58861832      +
# 5         sgA1BG_6   A1BG  chr19   58861742   58861762      -
# 6         sgA1BG_7   A1BG  chr19   58858896   58858916      +
# 7         sgA1BG_8   A1BG  chr19   58858825   58858845      +
# 8         sgA1BG_9   A1BG  chr19   58863885   58863905      +
# 9        sgA1BG_10   A1BG  chr19   58863843   58863863      -
# 10        sgA1CF_1   A1CF  chr10   52603833   52603853      +
# 11        sgA1CF_2   A1CF  chr10   52595871   52595891      +
# 12        sgA1CF_3   A1CF  chr10   52595858   52595878      -
# 13        sgA1CF_4   A1CF  chr10   52575997   52576017      -
# 14        sgA1CF_5   A1CF  chr10   52575882   52575902      -
# 15        sgA1CF_6   A1CF  chr10   52575758   52575778      +
# 16        sgA1CF_7   A1CF  chr10   52569780   52569800      +
# 17        sgA1CF_8   A1CF  chr10   52573621   52573641      +
# 18        sgA1CF_9   A1CF  chr10   52575902   52575922      +
# 19       sgA1CF_10   A1CF  chr10   52573774   52573794      -
# 20         sgA2M_1    A2M  chr12    9254210    9254230      -
# 21         sgA2M_2    A2M  chr12    9251312    9251332      +
# 22         sgA2M_3    A2M  chr12    9227344    9227364      -
# 23         sgA2M_4    A2M  chr12    9265042    9265062      -
# 24         sgA2M_5    A2M  chr12    9264747    9264767      +
# 25         sgA2M_6    A2M  chr12    9260143    9260163      +
# 26         sgA2M_7    A2M  chr12    9254138    9254158      +
# 27         sgA2M_8    A2M  chr12    9251283    9251303      +
# 28         sgA2M_9    A2M  chr12    9242992    9243012      -
# 29        sgA2M_10    A2M  chr12    9227236    9227256      -
# ...            ...    ...    ...        ...        ...    ...
# 181100     sgZYX_1    ZYX   chr7  143078677  143078697      -
# 181101     sgZYX_2    ZYX   chr7  143078733  143078753      +
# 181102     sgZYX_3    ZYX   chr7  143079349  143079369      -
# 181103     sgZYX_4    ZYX   chr7  143079928  143079948      -
# 181104     sgZYX_5    ZYX   chr7  143080017  143080037      -
# 181105     sgZYX_6    ZYX   chr7  143085391  143085411      +
# 181106     sgZYX_7    ZYX   chr7  143085676  143085696      -
# 181107     sgZYX_8    ZYX   chr7  143085847  143085867      +
# 181108     sgZYX_9    ZYX   chr7  143085921  143085941      -
# 181109    sgZYX_10    ZYX   chr7  143086961  143086981      -
# 181110   sgZZEF1_1  ZZEF1  chr17    4045901    4045921      +
# 181111   sgZZEF1_2  ZZEF1  chr17    4027269    4027289      -
# 181112   sgZZEF1_3  ZZEF1  chr17    3926024    3926044      -
# 181113   sgZZEF1_4  ZZEF1  chr17    4046169    4046189      +
# 181114   sgZZEF1_5  ZZEF1  chr17    4046140    4046160      -
# 181115   sgZZEF1_6  ZZEF1  chr17    4045877    4045897      -
# 181116   sgZZEF1_7  ZZEF1  chr17    4020351    4020371      +
# 181117   sgZZEF1_8  ZZEF1  chr17    4020336    4020356      +
# 181118   sgZZEF1_9  ZZEF1  chr17    4013124    4013144      -
# 181119  sgZZEF1_10  ZZEF1  chr17    3992043    3992063      -
# 181120    sgZZZ3_1   ZZZ3   chr1   78098079   78098099      -
# 181121    sgZZZ3_2   ZZZ3   chr1   78098998   78099018      -
# 181122    sgZZZ3_3   ZZZ3   chr1   78098602   78098622      -
# 181123    sgZZZ3_4   ZZZ3   chr1   78097874   78097894      -
# 181124    sgZZZ3_5   ZZZ3   chr1   78041808   78041828      +
# 181125    sgZZZ3_6   ZZZ3   chr1   78098450   78098470      -
# 181126    sgZZZ3_7   ZZZ3   chr1   78097975   78097995      +
# 181127    sgZZZ3_8   ZZZ3   chr1   78097958   78097978      +
# 181128    sgZZZ3_9   ZZZ3   chr1   78097861   78097881      +
# 181129   sgZZZ3_10   ZZZ3   chr1   78097668   78097688      -
#
#                     sequence      sequence_revComp                   oligo_F  \
# 0       CCAGCTGTTCAAGAATGGGG  CCCCATTCTTGAACAGCTGG  ACCGCCAGCTGTTCAAGAATGGGG
# 1       GTCGAGCTGATTCTGAGCGA  TCGCTCAGAATCAGCTCGAC  ACCGGTCGAGCTGATTCTGAGCGA
# 2       AGGCTGATGGACTGGAAAGG  CCTTTCCAGTCCATCAGCCT  ACCGAGGCTGATGGACTGGAAAGG
# 3       CTGGTGCGCGAGGACAGGGG  CCCCTGTCCTCGCGCACCAG  ACCGCTGGTGCGCGAGGACAGGGG
# 4       GTAGTTGGCGGAGTCAGCCA  TGGCTGACTCCGCCAACTAC  ACCGGTAGTTGGCGGAGTCAGCCA
# 5       CGAGCGCTTGGAGCTGCACG  CGTGCAGCTCCAAGCGCTCG  ACCGCGAGCGCTTGGAGCTGCACG
# 6       GCAGCTCGAAGGTGACGTCG  CGACGTCACCTTCGAGCTGC  ACCGGCAGCTCGAAGGTGACGTCG
# 7       GATCAGCTCGAGGTTCGCCG  CGGCGAACCTCGAGCTGATC  ACCGGATCAGCTCGAGGTTCGCCG
# 8       ACTGGCGCCATCGAGAGCCA  TGGCTCTCGATGGCGCCAGT  ACCGACTGGCGCCATCGAGAGCCA
# 9       AAAACAACAGCAGTGTGCCG  CGGCACACTGCTGTTGTTTT  ACCGAAAACAACAGCAGTGTGCCG
# 10      GCAGCATCCCAACCAGGTGG  CCACCTGGTTGGGATGCTGC  ACCGGCAGCATCCCAACCAGGTGG
# 11      ATGACTCTCATACTCCACGA  TCGTGGAGTATGAGAGTCAT  ACCGATGACTCTCATACTCCACGA
# 12      GAGTCATCGAGCAGCTGCCA  TGGCAGCTGCTCGATGACTC  ACCGGAGTCATCGAGCAGCTGCCA
# 13      AGTCACCCTAGCAAAACCAG  CTGGTTTTGCTAGGGTGACT  ACCGAGTCACCCTAGCAAAACCAG
# 14      GATCCCACCACAACCTACCT  AGGTAGGTTGTGGTGGGATC  ACCGGATCCCACCACAACCTACCT
# 15      GGTGTTACCTCTAACAGAAG  CTTCTGTTAGAGGTAACACC  ACCGGGTGTTACCTCTAACAGAAG
# 16      GCTTTGGAGGTGTGAAAGGG  CCCTTTCACACCTCCAAAGC  ACCGGCTTTGGAGGTGTGAAAGGG
# 17      GGAGCGAGTTTAATTCCTTG  CAAGGAATTAAACTCGCTCC  ACCGGGAGCGAGTTTAATTCCTTG
# 18      ATAAACTTGGCCCAAAGAGT  ACTCTTTGGGCCAAGTTTAT  ACCGATAAACTTGGCCCAAAGAGT
# 19      GCGGGAGTGAGAGGACTGGG  CCCAGTCCTCTCACTCCCGC  ACCGGCGGGAGTGAGAGGACTGGG
# 20      GGTGTCAGAAGAACACGAAG  CTTCGTGTTCTTCTGACACC  ACCGGGTGTCAGAAGAACACGAAG
# 21      GAGGCTGGGAGACTTTGTGA  TCACAAAGTCTCCCAGCCTC  ACCGGAGGCTGGGAGACTTTGTGA
# 22      GGAGCGCCCTCAGAAACCCA  TGGGTTTCTGAGGGCGCTCC  ACCGGGAGCGCCCTCAGAAACCCA
# 23      TAAGAAGCGGACCACAGTGA  TCACTGTGGTCCGCTTCTTA  ACCGTAAGAAGCGGACCACAGTGA
# 24      AAACTCACCAACTCATTCAG  CTGAATGAGTTGGTGAGTTT  ACCGAAACTCACCAACTCATTCAG
# 25      AAGCCTGTGAATCTTCACCG  CGGTGAAGATTCACAGGCTT  ACCGAAGCCTGTGAATCTTCACCG
# 26      CATGAGACATGGGCTCAAGG  CCTTGAGCCCATGTCTCATG  ACCGCATGAGACATGGGCTCAAGG
# 27      GAGCCGCTGTGACTCGCAGG  CCTGCGAGTCACAGCGGCTC  ACCGGAGCCGCTGTGACTCGCAGG
# 28      ACTGCATCTGTGCAAACGGG  CCCGTTTGCACAGATGCAGT  ACCGACTGCATCTGTGCAAACGGG
# 29      CCAGCCAGCCCCAACCTCGG  CCGAGGTTGGGGCTGGCTGG  ACCGCCAGCCAGCCCCAACCTCGG
# ...                      ...                   ...                       ...
# 181100  GAGATCGCGGGAGACGGGCG  CGCCCGTCTCCCGCGATCTC  ACCGGAGATCGCGGGAGACGGGCG
# 181101  GAAGAAGTTCGGCCCTGTGG  CCACAGGGCCGAACTTCTTC  ACCGGAAGAAGTTCGGCCCTGTGG
# 181102  GCAAGGGGAGGTGGAGGCAG  CTGCCTCCACCTCCCCTTGC  ACCGGCAAGGGGAGGTGGAGGCAG
# 181103  GGACTTGGAACTGAATGGAG  CTCCATTCAGTTCCAAGTCC  ACCGGGACTTGGAACTGAATGGAG
# 181104  GGAGCCGGAACCTGGGGCAG  CTGCCCCAGGTTCCGGCTCC  ACCGGGAGCCGGAACCTGGGGCAG
# 181105  AGGACATGGAGCATCCTCAG  CTGAGGATGCTCCATGTCCT  ACCGAGGACATGGAGCATCCTCAG
# 181106  GGAGCTGCTGCGCACACTGG  CCAGTGTGCGCAGCAGCTCC  ACCGGGAGCTGCTGCGCACACTGG
# 181107  GCTGCCTCCTCAGGACACCC  GGGTGTCCTGAGGAGGCAGC  ACCGGCTGCCTCCTCAGGACACCC
# 181108  CGGGTGATAGGCCTTGCCCG  CGGGCAAGGCCTATCACCCG  ACCGCGGGTGATAGGCCTTGCCCG
# 181109  AGAGCAGACGGAGCACCTCG  CGAGGTGCTCCGTCTGCTCT  ACCGAGAGCAGACGGAGCACCTCG
# 181110  GAGTGACAGACTCTTCGCCG  CGGCGAAGAGTCTGTCACTC  ACCGGAGTGACAGACTCTTCGCCG
# 181111  GAGGCCCTCAAGAATTCCAG  CTGGAATTCTTGAGGGCCTC  ACCGGAGGCCCTCAAGAATTCCAG
# 181112  GGACTGGCTTTAGTAAAACG  CGTTTTACTAAAGCCAGTCC  ACCGGGACTGGCTTTAGTAAAACG
# 181113  GTGACTCGGAGCGTTCCCCA  TGGGGAACGCTCCGAGTCAC  ACCGGTGACTCGGAGCGTTCCCCA
# 181114  GACGAAGCGGCAGCTGCCGG  CCGGCAGCTGCCGCTTCGTC  ACCGGACGAAGCGGCAGCTGCCGG
# 181115  GCAGTTCCGGGAGCTGCTGG  CCAGCAGCTCCCGGAACTGC  ACCGGCAGTTCCGGGAGCTGCTGG
# 181116  CGGGTAGGGCATCACCGCGC  GCGCGGTGATGCCCTACCCG  ACCGCGGGTAGGGCATCACCGCGC
# 181117  GCAGTGCTCCAGCATCGGGT  ACCCGATGCTGGAGCACTGC  ACCGGCAGTGCTCCAGCATCGGGT
# 181118  ATAAAGCGTTGTCTTAGCGA  TCGCTAAGACAACGCTTTAT  ACCGATAAAGCGTTGTCTTAGCGA
# 181119  ACACTGCAGAAAGGACACAG  CTGTGTCCTTTCTGCAGTGT  ACCGACACTGCAGAAAGGACACAG
# 181120  TGAGGAGGAAGTAGATGTGG  CCACATCTACTTCCTCCTCA  ACCGTGAGGAGGAAGTAGATGTGG
# 181121  GTGTTACAAGATCAACAGTG  CACTGTTGATCTTGTAACAC  ACCGGTGTTACAAGATCAACAGTG
# 181122  ACAAGGAGTCAGTAGAACAG  CTGTTCTACTGACTCCTTGT  ACCGACAAGGAGTCAGTAGAACAG
# 181123  CGAAGGGCAGCCCCTACCAG  CTGGTAGGGGCTGCCCTTCG  ACCGCGAAGGGCAGCCCCTACCAG
# 181124  TCTTCATCCATATACACTGG  CCAGTGTATATGGATGAAGA  ACCGTCTTCATCCATATACACTGG
# 181125  GCAGTAGTTGAAGAAATCAC  GTGATTTCTTCAACTACTGC  ACCGGCAGTAGTTGAAGAAATCAC
# 181126  AGATGGTTCAGGTTCTCCGG  CCGGAGAACCTGAACCATCT  ACCGAGATGGTTCAGGTTCTCCGG
# 181127  ACACAGTCTAGAACAGGAGA  TCTCCTGTTCTAGACTGTGT  ACCGACACAGTCTAGAACAGGAGA
# 181128  AGTGGGACTACCTCTGGTAG  CTACCAGAGGTAGTCCCACT  ACCGAGTGGGACTACCTCTGGTAG
# 181129  AGTAAGTAAACCACCCTCAG  CTGAGGGTGGTTTACTTACT  ACCGAGTAAGTAAACCACCCTCAG
#
#                          oligo_R
# 0       AAACCCCCATTCTTGAACAGCTGG
# 1       AAACTCGCTCAGAATCAGCTCGAC
# 2       AAACCCTTTCCAGTCCATCAGCCT
# 3       AAACCCCCTGTCCTCGCGCACCAG
# 4       AAACTGGCTGACTCCGCCAACTAC
# 5       AAACCGTGCAGCTCCAAGCGCTCG
# 6       AAACCGACGTCACCTTCGAGCTGC
# 7       AAACCGGCGAACCTCGAGCTGATC
# 8       AAACTGGCTCTCGATGGCGCCAGT
# 9       AAACCGGCACACTGCTGTTGTTTT
# 10      AAACCCACCTGGTTGGGATGCTGC
# 11      AAACTCGTGGAGTATGAGAGTCAT
# 12      AAACTGGCAGCTGCTCGATGACTC
# 13      AAACCTGGTTTTGCTAGGGTGACT
# 14      AAACAGGTAGGTTGTGGTGGGATC
# 15      AAACCTTCTGTTAGAGGTAACACC
# 16      AAACCCCTTTCACACCTCCAAAGC
# 17      AAACCAAGGAATTAAACTCGCTCC
# 18      AAACACTCTTTGGGCCAAGTTTAT
# 19      AAACCCCAGTCCTCTCACTCCCGC
# 20      AAACCTTCGTGTTCTTCTGACACC
# 21      AAACTCACAAAGTCTCCCAGCCTC
# 22      AAACTGGGTTTCTGAGGGCGCTCC
# 23      AAACTCACTGTGGTCCGCTTCTTA
# 24      AAACCTGAATGAGTTGGTGAGTTT
# 25      AAACCGGTGAAGATTCACAGGCTT
# 26      AAACCCTTGAGCCCATGTCTCATG
# 27      AAACCCTGCGAGTCACAGCGGCTC
# 28      AAACCCCGTTTGCACAGATGCAGT
# 29      AAACCCGAGGTTGGGGCTGGCTGG
# ...                          ...
# 181100  AAACCGCCCGTCTCCCGCGATCTC
# 181101  AAACCCACAGGGCCGAACTTCTTC
# 181102  AAACCTGCCTCCACCTCCCCTTGC
# 181103  AAACCTCCATTCAGTTCCAAGTCC
# 181104  AAACCTGCCCCAGGTTCCGGCTCC
# 181105  AAACCTGAGGATGCTCCATGTCCT
# 181106  AAACCCAGTGTGCGCAGCAGCTCC
# 181107  AAACGGGTGTCCTGAGGAGGCAGC
# 181108  AAACCGGGCAAGGCCTATCACCCG
# 181109  AAACCGAGGTGCTCCGTCTGCTCT
# 181110  AAACCGGCGAAGAGTCTGTCACTC
# 181111  AAACCTGGAATTCTTGAGGGCCTC
# 181112  AAACCGTTTTACTAAAGCCAGTCC
# 181113  AAACTGGGGAACGCTCCGAGTCAC
# 181114  AAACCCGGCAGCTGCCGCTTCGTC
# 181115  AAACCCAGCAGCTCCCGGAACTGC
# 181116  AAACGCGCGGTGATGCCCTACCCG
# 181117  AAACACCCGATGCTGGAGCACTGC
# 181118  AAACTCGCTAAGACAACGCTTTAT
# 181119  AAACCTGTGTCCTTTCTGCAGTGT
# 181120  AAACCCACATCTACTTCCTCCTCA
# 181121  AAACCACTGTTGATCTTGTAACAC
# 181122  AAACCTGTTCTACTGACTCCTTGT
# 181123  AAACCTGGTAGGGGCTGCCCTTCG
# 181124  AAACCCAGTGTATATGGATGAAGA
# 181125  AAACGTGATTTCTTCAACTACTGC
# 181126  AAACCCGGAGAACCTGAACCATCT
# 181127  AAACTCTCCTGTTCTAGACTGTGT
# 181128  AAACCTACCAGAGGTAGTCCCACT
# 181129  AAACCTGAGGGTGGTTTACTTACT
#
# [181130 rows x 10 columns]

# %%
clinvar = pd.read_csv(CAforDS.raw.clinvar(),
                      sep='\t',
                      comment='#',
                      names=['CHROM', 'POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO'])

# %%
clinvar
# Out:
#      CHROM        POS           ID REF    ALT QUAL FILTER  \
# 0        1     955619  rs201073369   G      C    .      .
# 1        1     957640    rs6657048   C      T    .      .
# 2        1     976059  rs544749044   C      T    .      .
# 3        1     979397  rs143324306   G      A    .      .
# 4        1     979514   rs28484890   C      G    .      .
# 5        1     980773   rs75774767   C      T    .      .
# 6        1     980824  rs112039851   G    A,C    .      .
# 7        1     982213  rs150132566   G    C,T    .      .
# 8        1     982722  rs142416636   A      G    .      .
# 9        1     982783  rs146358566   T      C    .      .
# 10       1     982844   rs76264143   G      C    .      .
# 11       1     983006   rs75361935   C      T    .      .
# 12       1     983506  rs139294803   C      T    .      .
# 13       1     983604  rs184970403   C      T    .      .
# 14       1     983612  rs201483077   G      A    .      .
# 15       1     984769   rs75767981   C      T    .      .
# 16       1     984971  rs111818381   G    A,C    .      .
# 17       1     985171  rs115019873   C      T    .      .
# 18       1     985826   rs17160775   G      A    .      .
# 19       1     986737   rs17160781   T      C    .      .
# 20       1     987142   rs17778478   C      T    .      .
# 21       1    1959699   rs41307846   G      A    .      .
# 22       1    2161003  rs149642284   C      T    .      .
# 23       1    2234791   rs75280988   C      T    .      .
# 24       1    2234824  rs141862996   C      T    .      .
# 25       1    2340200    rs2494598   T    A,C    .      .
# 26       1    2340212    rs1143016   G      A    .      .
# 27       1    5924518  rs115526767   G      A    .      .
# 28       1    5927169  rs113445782   G      A    .      .
# 29       1    5935102   rs12084067   C      T    .      .
# ...    ...        ...          ...  ..    ...  ...    ...
# 5777     X  153580576  rs113510895   G      A    .      .
# 5778     X  153580676    rs1064822   C      G    .      .
# 5779     X  153581582   rs72616474   G      C    .      .
# 5780     X  153581714  rs187029309   G      A    .      .
# 5781     X  153581932    rs2070825   A      G    .      .
# 5782     X  153581968  rs140084263   G      A    .      .
# 5783     X  153583007   rs57108893   C      T    .      .
# 5784     X  153585827   rs61741041   C      T    .      .
# 5785     X  153587684   rs34439033   C      T    .      .
# 5786     X  153588473   rs35015603   G      A    .      .
# 5787     X  153588893   rs79391751   G      A    .      .
# 5788     X  153589848   rs17091204   G      A    .      .
# 5789     X  153592948   rs73638274   G      A    .      .
# 5790     X  153594535   rs36051194   G      A    .      .
# 5791     X  153596066    rs2073470   G      A    .      .
# 5792     X  153629155   rs12012747   A      G    .      .
# 5793     X  153642450  rs146934311   T      C    .      .
# 5794     X  153667108  rs113696246   C      T    .      .
# 5795     X  153667422    rs2230286   C      T    .      .
# 5796     X  153760472   rs72554664   C      T    .      .
# 5797     X  153760484   rs72554665   C  A,G,T    .      .
# 5798     X  153760654    rs2230037   G      A    .      .
# 5799     X  153761240   rs76723693   A      G    .      .
# 5800     X  153761259  rs137852339   C      T    .      .
# 5801     X  153761337  rs137852327   C      T    .      .
# 5802     X  153762634    rs5030868   G      A    .      .
# 5803     X  153763492    rs1050829   T    A,C    .      .
# 5804     X  153764217    rs1050828   C      T    .      .
# 5805     X  154004584    rs1127051   C      T    .      .
# 5806     X  154159682    rs2228152   T    A,C    .      .
#
#                                                    INFO
# 0     RS=201073369;RSPOS=955619;dbSNPBuildID=137;SSR...
# 1     RS=6657048;RSPOS=957640;dbSNPBuildID=116;SSR=0...
# 2     RS=544749044;RSPOS=976059;dbSNPBuildID=142;SSR...
# 3     RS=143324306;RSPOS=979397;dbSNPBuildID=134;SSR...
# 4     RS=28484890;RSPOS=979514;dbSNPBuildID=125;SSR=...
# 5     RS=75774767;RSPOS=980773;dbSNPBuildID=131;SSR=...
# 6     RS=112039851;RSPOS=980824;dbSNPBuildID=132;SSR...
# 7     RS=150132566;RSPOS=982213;dbSNPBuildID=134;SSR...
# 8     RS=142416636;RSPOS=982722;dbSNPBuildID=134;SSR...
# 9     RS=146358566;RSPOS=982783;dbSNPBuildID=134;SSR...
# 10    RS=76264143;RSPOS=982844;dbSNPBuildID=132;SSR=...
# 11    RS=75361935;RSPOS=983006;dbSNPBuildID=131;SSR=...
# 12    RS=139294803;RSPOS=983506;dbSNPBuildID=134;SSR...
# 13    RS=184970403;RSPOS=983604;dbSNPBuildID=135;SSR...
# 14    RS=201483077;RSPOS=983612;dbSNPBuildID=137;SSR...
# 15    RS=75767981;RSPOS=984769;dbSNPBuildID=131;SSR=...
# 16    RS=111818381;RSPOS=984971;dbSNPBuildID=132;SSR...
# 17    RS=115019873;RSPOS=985171;dbSNPBuildID=132;SSR...
# 18    RS=17160775;RSPOS=985826;dbSNPBuildID=123;SSR=...
# 19    RS=17160781;RSPOS=986737;dbSNPBuildID=123;SSR=...
# 20    RS=17778478;RSPOS=987142;dbSNPBuildID=123;SSR=...
# 21    RS=41307846;RSPOS=1959699;dbSNPBuildID=127;SSR...
# 22    RS=149642284;RSPOS=2161003;dbSNPBuildID=134;SS...
# 23    RS=75280988;RSPOS=2234791;dbSNPBuildID=131;SSR...
# 24    RS=141862996;RSPOS=2234824;dbSNPBuildID=134;SS...
# 25    RS=2494598;RSPOS=2340200;RV;dbSNPBuildID=100;S...
# 26    RS=1143016;RSPOS=2340212;RV;dbSNPBuildID=86;SS...
# 27    RS=115526767;RSPOS=5924518;dbSNPBuildID=132;SS...
# 28    RS=113445782;RSPOS=5927169;dbSNPBuildID=132;SS...
# 29    RS=12084067;RSPOS=5935102;dbSNPBuildID=120;SSR...
# ...                                                 ...
# 5777  RS=113510895;RSPOS=153580576;dbSNPBuildID=132;...
# 5778  RS=1064822;RSPOS=153580676;dbSNPBuildID=86;SSR...
# 5779  RS=72616474;RSPOS=153581582;dbSNPBuildID=130;S...
# 5780  RS=187029309;RSPOS=153581714;dbSNPBuildID=135;...
# 5781  RS=2070825;RSPOS=153581932;dbSNPBuildID=96;SSR...
# 5782  RS=140084263;RSPOS=153581968;dbSNPBuildID=134;...
# 5783  RS=57108893;RSPOS=153583007;dbSNPBuildID=129;S...
# 5784  RS=61741041;RSPOS=153585827;dbSNPBuildID=129;S...
# 5785  RS=34439033;RSPOS=153587684;RV;dbSNPBuildID=12...
# 5786  RS=35015603;RSPOS=153588473;RV;dbSNPBuildID=12...
# 5787  RS=79391751;RSPOS=153588893;dbSNPBuildID=131;S...
# 5788  RS=17091204;RSPOS=153589848;dbSNPBuildID=123;S...
# 5789  RS=73638274;RSPOS=153592948;dbSNPBuildID=130;S...
# 5790  RS=36051194;RSPOS=153594535;RV;dbSNPBuildID=12...
# 5791  RS=2073470;RSPOS=153596066;dbSNPBuildID=96;SSR...
# 5792  RS=12012747;RSPOS=153629155;dbSNPBuildID=126;S...
# 5793  RS=146934311;RSPOS=153642450;dbSNPBuildID=134;...
# 5794  RS=113696246;RSPOS=153667108;dbSNPBuildID=132;...
# 5795  RS=2230286;RSPOS=153667422;dbSNPBuildID=98;SSR...
# 5796  RS=72554664;RSPOS=153760472;RV;dbSNPBuildID=13...
# 5797  RS=72554665;RSPOS=153760484;RV;dbSNPBuildID=13...
# 5798  RS=2230037;RSPOS=153760654;RV;dbSNPBuildID=98;...
# 5799  RS=76723693;RSPOS=153761240;RV;dbSNPBuildID=13...
# 5800  RS=137852339;RSPOS=153761259;RV;dbSNPBuildID=1...
# 5801  RS=137852327;RSPOS=153761337;RV;dbSNPBuildID=1...
# 5802  RS=5030868;RSPOS=153762634;RV;dbSNPBuildID=113...
# 5803  RS=1050829;RSPOS=153763492;RV;dbSNPBuildID=86;...
# 5804  RS=1050828;RSPOS=153764217;RV;dbSNPBuildID=86;...
# 5805  RS=1127051;RSPOS=154004584;dbSNPBuildID=102;SS...
# 5806  RS=2228152;RSPOS=154159682;RV;dbSNPBuildID=98;...
#
# [5807 rows x 8 columns]

# %%
a = clinvar
b = lander

a['Chromosome'] = a['CHROM'].apply(lambda x: "chr%s" %x)
a
# Out:
#      CHROM        POS           ID REF    ALT QUAL FILTER  \
# 0        1     955619  rs201073369   G      C    .      .
# 1        1     957640    rs6657048   C      T    .      .
# 2        1     976059  rs544749044   C      T    .      .
# 3        1     979397  rs143324306   G      A    .      .
# 4        1     979514   rs28484890   C      G    .      .
# 5        1     980773   rs75774767   C      T    .      .
# 6        1     980824  rs112039851   G    A,C    .      .
# 7        1     982213  rs150132566   G    C,T    .      .
# 8        1     982722  rs142416636   A      G    .      .
# 9        1     982783  rs146358566   T      C    .      .
# 10       1     982844   rs76264143   G      C    .      .
# 11       1     983006   rs75361935   C      T    .      .
# 12       1     983506  rs139294803   C      T    .      .
# 13       1     983604  rs184970403   C      T    .      .
# 14       1     983612  rs201483077   G      A    .      .
# 15       1     984769   rs75767981   C      T    .      .
# 16       1     984971  rs111818381   G    A,C    .      .
# 17       1     985171  rs115019873   C      T    .      .
# 18       1     985826   rs17160775   G      A    .      .
# 19       1     986737   rs17160781   T      C    .      .
# 20       1     987142   rs17778478   C      T    .      .
# 21       1    1959699   rs41307846   G      A    .      .
# 22       1    2161003  rs149642284   C      T    .      .
# 23       1    2234791   rs75280988   C      T    .      .
# 24       1    2234824  rs141862996   C      T    .      .
# 25       1    2340200    rs2494598   T    A,C    .      .
# 26       1    2340212    rs1143016   G      A    .      .
# 27       1    5924518  rs115526767   G      A    .      .
# 28       1    5927169  rs113445782   G      A    .      .
# 29       1    5935102   rs12084067   C      T    .      .
# ...    ...        ...          ...  ..    ...  ...    ...
# 5777     X  153580576  rs113510895   G      A    .      .
# 5778     X  153580676    rs1064822   C      G    .      .
# 5779     X  153581582   rs72616474   G      C    .      .
# 5780     X  153581714  rs187029309   G      A    .      .
# 5781     X  153581932    rs2070825   A      G    .      .
# 5782     X  153581968  rs140084263   G      A    .      .
# 5783     X  153583007   rs57108893   C      T    .      .
# 5784     X  153585827   rs61741041   C      T    .      .
# 5785     X  153587684   rs34439033   C      T    .      .
# 5786     X  153588473   rs35015603   G      A    .      .
# 5787     X  153588893   rs79391751   G      A    .      .
# 5788     X  153589848   rs17091204   G      A    .      .
# 5789     X  153592948   rs73638274   G      A    .      .
# 5790     X  153594535   rs36051194   G      A    .      .
# 5791     X  153596066    rs2073470   G      A    .      .
# 5792     X  153629155   rs12012747   A      G    .      .
# 5793     X  153642450  rs146934311   T      C    .      .
# 5794     X  153667108  rs113696246   C      T    .      .
# 5795     X  153667422    rs2230286   C      T    .      .
# 5796     X  153760472   rs72554664   C      T    .      .
# 5797     X  153760484   rs72554665   C  A,G,T    .      .
# 5798     X  153760654    rs2230037   G      A    .      .
# 5799     X  153761240   rs76723693   A      G    .      .
# 5800     X  153761259  rs137852339   C      T    .      .
# 5801     X  153761337  rs137852327   C      T    .      .
# 5802     X  153762634    rs5030868   G      A    .      .
# 5803     X  153763492    rs1050829   T    A,C    .      .
# 5804     X  153764217    rs1050828   C      T    .      .
# 5805     X  154004584    rs1127051   C      T    .      .
# 5806     X  154159682    rs2228152   T    A,C    .      .
#
#                                                    INFO Chromosome
# 0     RS=201073369;RSPOS=955619;dbSNPBuildID=137;SSR...       chr1
# 1     RS=6657048;RSPOS=957640;dbSNPBuildID=116;SSR=0...       chr1
# 2     RS=544749044;RSPOS=976059;dbSNPBuildID=142;SSR...       chr1
# 3     RS=143324306;RSPOS=979397;dbSNPBuildID=134;SSR...       chr1
# 4     RS=28484890;RSPOS=979514;dbSNPBuildID=125;SSR=...       chr1
# 5     RS=75774767;RSPOS=980773;dbSNPBuildID=131;SSR=...       chr1
# 6     RS=112039851;RSPOS=980824;dbSNPBuildID=132;SSR...       chr1
# 7     RS=150132566;RSPOS=982213;dbSNPBuildID=134;SSR...       chr1
# 8     RS=142416636;RSPOS=982722;dbSNPBuildID=134;SSR...       chr1
# 9     RS=146358566;RSPOS=982783;dbSNPBuildID=134;SSR...       chr1
# 10    RS=76264143;RSPOS=982844;dbSNPBuildID=132;SSR=...       chr1
# 11    RS=75361935;RSPOS=983006;dbSNPBuildID=131;SSR=...       chr1
# 12    RS=139294803;RSPOS=983506;dbSNPBuildID=134;SSR...       chr1
# 13    RS=184970403;RSPOS=983604;dbSNPBuildID=135;SSR...       chr1
# 14    RS=201483077;RSPOS=983612;dbSNPBuildID=137;SSR...       chr1
# 15    RS=75767981;RSPOS=984769;dbSNPBuildID=131;SSR=...       chr1
# 16    RS=111818381;RSPOS=984971;dbSNPBuildID=132;SSR...       chr1
# 17    RS=115019873;RSPOS=985171;dbSNPBuildID=132;SSR...       chr1
# 18    RS=17160775;RSPOS=985826;dbSNPBuildID=123;SSR=...       chr1
# 19    RS=17160781;RSPOS=986737;dbSNPBuildID=123;SSR=...       chr1
# 20    RS=17778478;RSPOS=987142;dbSNPBuildID=123;SSR=...       chr1
# 21    RS=41307846;RSPOS=1959699;dbSNPBuildID=127;SSR...       chr1
# 22    RS=149642284;RSPOS=2161003;dbSNPBuildID=134;SS...       chr1
# 23    RS=75280988;RSPOS=2234791;dbSNPBuildID=131;SSR...       chr1
# 24    RS=141862996;RSPOS=2234824;dbSNPBuildID=134;SS...       chr1
# 25    RS=2494598;RSPOS=2340200;RV;dbSNPBuildID=100;S...       chr1
# 26    RS=1143016;RSPOS=2340212;RV;dbSNPBuildID=86;SS...       chr1
# 27    RS=115526767;RSPOS=5924518;dbSNPBuildID=132;SS...       chr1
# 28    RS=113445782;RSPOS=5927169;dbSNPBuildID=132;SS...       chr1
# 29    RS=12084067;RSPOS=5935102;dbSNPBuildID=120;SSR...       chr1
# ...                                                 ...        ...
# 5777  RS=113510895;RSPOS=153580576;dbSNPBuildID=132;...       chrX
# 5778  RS=1064822;RSPOS=153580676;dbSNPBuildID=86;SSR...       chrX
# 5779  RS=72616474;RSPOS=153581582;dbSNPBuildID=130;S...       chrX
# 5780  RS=187029309;RSPOS=153581714;dbSNPBuildID=135;...       chrX
# 5781  RS=2070825;RSPOS=153581932;dbSNPBuildID=96;SSR...       chrX
# 5782  RS=140084263;RSPOS=153581968;dbSNPBuildID=134;...       chrX
# 5783  RS=57108893;RSPOS=153583007;dbSNPBuildID=129;S...       chrX
# 5784  RS=61741041;RSPOS=153585827;dbSNPBuildID=129;S...       chrX
# 5785  RS=34439033;RSPOS=153587684;RV;dbSNPBuildID=12...       chrX
# 5786  RS=35015603;RSPOS=153588473;RV;dbSNPBuildID=12...       chrX
# 5787  RS=79391751;RSPOS=153588893;dbSNPBuildID=131;S...       chrX
# 5788  RS=17091204;RSPOS=153589848;dbSNPBuildID=123;S...       chrX
# 5789  RS=73638274;RSPOS=153592948;dbSNPBuildID=130;S...       chrX
# 5790  RS=36051194;RSPOS=153594535;RV;dbSNPBuildID=12...       chrX
# 5791  RS=2073470;RSPOS=153596066;dbSNPBuildID=96;SSR...       chrX
# 5792  RS=12012747;RSPOS=153629155;dbSNPBuildID=126;S...       chrX
# 5793  RS=146934311;RSPOS=153642450;dbSNPBuildID=134;...       chrX
# 5794  RS=113696246;RSPOS=153667108;dbSNPBuildID=132;...       chrX
# 5795  RS=2230286;RSPOS=153667422;dbSNPBuildID=98;SSR...       chrX
# 5796  RS=72554664;RSPOS=153760472;RV;dbSNPBuildID=13...       chrX
# 5797  RS=72554665;RSPOS=153760484;RV;dbSNPBuildID=13...       chrX
# 5798  RS=2230037;RSPOS=153760654;RV;dbSNPBuildID=98;...       chrX
# 5799  RS=76723693;RSPOS=153761240;RV;dbSNPBuildID=13...       chrX
# 5800  RS=137852339;RSPOS=153761259;RV;dbSNPBuildID=1...       chrX
# 5801  RS=137852327;RSPOS=153761337;RV;dbSNPBuildID=1...       chrX
# 5802  RS=5030868;RSPOS=153762634;RV;dbSNPBuildID=113...       chrX
# 5803  RS=1050829;RSPOS=153763492;RV;dbSNPBuildID=86;...       chrX
# 5804  RS=1050828;RSPOS=153764217;RV;dbSNPBuildID=86;...       chrX
# 5805  RS=1127051;RSPOS=154004584;dbSNPBuildID=102;SS...       chrX
# 5806  RS=2228152;RSPOS=154159682;RV;dbSNPBuildID=98;...       chrX
#
# [5807 rows x 9 columns]

# %%
matches = 0
count = 0
signal.alarm(timer)
try:
    starttime = time.time()
    for idx, a_row in a.iterrows():
        a_match = b.loc[(b['chr'] == a_row['Chromosome']) & (a_row['POS'] >= b['start']) & ((a_row['POS'] <= b['stop']))]
        matches += len(a_match)
        count += b_len
    endtime = time.time()
    print("Done, found %s matches in %ds" % (matches, endtime-starttime))
except TimerException:
    print("Excecuted %ss" % timer)
finally:
    signal.alarm(0)
    miterations = count/1000000.0
    print("Completed {it}M iterations".format(it=miterations))
# Out:
# Stopped
# Excecuted 30s
# Completed 4882.463238M iterations

# %%
matches = 0
count = 0
signal.alarm(timer)
try:
    starttime = time.time()
    b_chr = b.groupby('chr')       
    for idx, a_row in a.iterrows():
        chr_grp = b_chr.get_group(a_row['Chromosome'])
        a_match = chr_grp.loc[(a_row['POS'] >= chr_grp['start']) & ((a_row['POS'] <= chr_grp['stop']))]
        matches += len(a_match)
        count += len(b_grp.index)
    endtime = time.time()
    print("Done, found %s matches in %ds" % (matches, endtime-starttime))
except TimerException:
    print("Excecuted %ss" % timer)
finally:
    signal.alarm(0)
    miterations = count/1000000.0
    print("Completed {it}M iterations".format(it=miterations))
# Out:
# Done, found 462 matches in 17s
# Completed 43.26215M iterations

# %%
count = 0
signal.alarm(timer)
matches = []
try:
    starttime = time.time()
    a_chrs = a.groupby('Chromosome')
    b_chrs = b.groupby('chr')
    
    for a_chr, a_grp in a_chrs:
        b_grp = b_chrs.get_group(a_chr)
        for idx, a_pos in a_grp['POS'].iteritems():
            a_match = b_grp.loc[(b_grp['start'] <= a_pos) & ((a_pos <= b_grp['stop']))]
            if len(a_match.index) > 0:
                matches.append(a_match)
            count += len(b_grp.index)
    allmatches = pd.concat(matches)
    endtime = time.time()
    print("Done, found %s matches in %ds" % (len(allmatches.index), endtime-starttime))
except TimerException:
    print("Excecuted %d iterations" % count)
finally:
    signal.alarm(0)
    miterations = count/1000000.0
    print("Completed {it}M iterations".format(it=miterations))
# Out:
# Done, found 462 matches in 5s
# Completed 53.85803M iterations

# %%
def profile_match(a, b):
    count = 0
    matches = []
    a_chrs = a.groupby('Chromosome')
    b_chrs = b.groupby('chr')
    
    for a_chr, a_grp in a_chrs:
        b_grp = b_chrs.get_group(a_chr)
        for idx, a_pos in a_grp['POS'].iteritems():
            a_match = b_grp.loc[(b_grp['start'] <= a_pos) & ((a_pos <= b_grp['stop']))]
            if len(a_match.index) > 0:
                matches.append(a_match)
            count += len(b_grp.index)
    allmatches = pd.concat(matches)
    return allmatches

# %prun -s cumulative profile_match(a,b)

# %%
dan = pd.read_csv('dan_genome/genome_Dan_Webster_v4_Full_20170504123348.txt',
                      sep='\t',
                      comment='#',
                      names=['rsid', 'chromosome', 'position', 'genotype'],
                      dtype={'chromosome' : 'category'})
